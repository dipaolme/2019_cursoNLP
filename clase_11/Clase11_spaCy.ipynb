# %% [markdown]
# Clase 11
#
# # <center>spaCy</center>
#
# ---
#
# [spaCy](https://spacy.io/) es una librería open-source diseñada para realizar tareas de NLP.
# Su código, disponible en [GitHub](https://github.com/explosion/spaCy), se encuentra escrito en Python y Cython. Este último permite enriquecer la escritura de Python con propiedades de los lenguajes C y C++, haciéndolo más eficiente.

# %% [markdown]
# **Guía de clase:**
#
# - [1. Importar la librería](#1.-Importar-la-librería)
# - [2. Configurar un pipeline](#2.-Configurar-un-pipeline)
# - [3. Doc](#3.-Doc)
# - [4. Tokenización](#4.-Tokenización)
# - [5. Etiquetado](#5.-Etiquetado)
# - [6. Parseo de dependencias](#6.-Parseo-de-dependencias)
# - [7. Segmentación de oraciones](#7.-Segmentación-de-oraciones)
# - [8. NER](#8.-NER)
# - [9. Matcheo-mediante-reglas](#9.-Matcheo-mediante-reglas)

# %% [markdown]
# ## 1. Importar la librería

# %%
import sys
sys.path.append("/home/dipa/proyectos/2019_cursoNLP/lib/python3.6/site-packages")
import spacy
from spacy import displacy

# %% [markdown]
# SpaCy cuenta con una serie de modelos pre-entrenados para distintas lenguas (inglés, alemán, español, francés, portugués, italiano, holandés y griego). Para poder usarlos, es necesarios instalarlos luego de instalar la librería, del mismo modo que instalamos cualquier paquete de Python.
#
# Asimismo, una vez importada la librería, debe instanciarse con el entrenamiento deseado. De él tomará los distintos componentes para los análisis lingüísticos.

# %%
# cargamos un entrenamiento en español

nlp = spacy.load("es_core_news_sm")

# %% [markdown]
# Actualmente, SpaCy cuenta con dos modelos pre-entrenados para el español:
#
# - es_core_news_sm: modelo multipropósito entrenado con textos de medios y redes sociales. Contiene componentes para realizar tokenización, POS tagging, parsers de dependencia y reconocer entidades (PER, LOC, ORG, MISC)
#
# - es_core_news_md: modelo multipropósito que, además de contener los componentes del modelo anterior, presenta un tamaño mayor e incluye vectores de palabras
#
# Ambos modelos toman como fuente textos extraídos de AnCora, Wikipedia y WikiNER Corpus.

# %% [markdown]
# ## 2. Configurar un pipeline

# %% [markdown]
# ![alt text](./pictures/pipeline.svg)

# %% [markdown]
# El atributo *pipe_names* nos permite acceder a los nombre de los componentes que se encuentran incluidos en el modelo. Estos se muestran en orden de ejecución.

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %% [markdown]
# Si no quisiéramos utilizar todos los componentes incluidos (ya sea porque no los necesitamos o porque queremos cambiar el componente por defecto por uno hecho por nosotros mismos), podemos deshabilitar aquellos que queramos excluir utilizando al momento de cargar el idioma, o bien deshabilitándolos luego con el método *disable_pipes*.

# %%
nlp_parser = spacy.load("es", disable=["ner", "tagger"])


nlp_parser.pipe_names
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-47c7ee08bcf5> in <module>
# ----> 1 nlp_parser = spacy.load("es", disable=["ner", "tagger"])
#       2
#       3
#       4 nlp_parser.pipe_names
#
# ~/proyectos/2019_cursoNLP/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~/proyectos/2019_cursoNLP/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     134     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     135         return load_model_from_path(name, **overrides)
# --> 136     raise IOError(Errors.E050.format(name=name))
#     137
#     138
#
# OSError: [E050] Can't find model 'es'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
disabled = nlp.disable_pipes('tagger', 'parser')
nlp.begin_training()

# %%
disabled
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x7f2f6af59ef0>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x7f2f6af45168>)]

# %%
nlp.pipe_names
# Out:
# ['ner']

# %% [markdown]
# Y también podemos restaurar los valores por default.

# %%
disabled.restore()

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %% [markdown]
# ## 3. Doc

# %% [markdown]
# SpaCy ya viene con información lingüística y anotaciones que podemos utilizar para enriquecer nuestros textos crudos. Para ello, debemos construir un objeto ```Doc```, el cual consite en una secuencia de objetos ```Token``` con distintas anotaciones según cuál sea el modelo pre-entrenado que estemos utilizando y cómo hayamos configurado nuestro pipeline.

# %%
with open('bestiario/casa_tomada.txt','r') as f:
    casa_tomada = f.read()

# %%
print(casa_tomada[:1000])
# Out:
# CASA TOMADA
#
#  	Nos gustaba la casa porque aparte de espaciosa y antigua (hoy que las casas antiguas sucumben a la más ventajosa liquidación de sus materiales) guardaba los recuerdos de nuestros bisabuelos, el abuelo paterno, nuestros padres y toda la infancia.
#  	Nos habituamos Irene y yo a persistir solos en ella, lo que era una locura pues en esa casa podían vivir ocho personas sin estorbarse. Hacíamos la limpieza por la mañana, levantándonos a las siete, y a eso de las once yo le dejaba a Irene las últimas habitaciones por repasar y me iba a la cocina. Almorzábamos a mediodía, siempre puntuales; ya no quedaba nada por hacer fuera de unos pocos platos sucios. Nos resultaba grato almorzar pensando en la casa profunda y silenciosa y cómo nos bastábamos para mantenerla limpia. A veces llegamos a creer que era ella la que no nos dejó casarnos. Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió María Esther antes que llegáramos a comprometernos. Entramos en los cuarenta año

# %%
doc = nlp(casa_tomada)

# %% [markdown]
# ## 4. Tokenización

# %%
import os
import re

# %% [markdown]
# Cantidad de tokens en el texto:

# %%
doc.__len__()
# Out:
# 2212

# %%
for token in doc[:20]:
    print(token.i, token.text)
# Out:
# 0 CASA
# 1 TOMADA
# 2
#
#
# 3 Nos
# 4 gustaba
# 5 la
# 6 casa
# 7 porque
# 8 aparte
# 9 de
# 10 espaciosa
# 11 y
# 12 antigua
# 13 (
# 14 hoy
# 15 que
# 16 las
# 17 casas
# 18 antiguas
# 19 sucumben

# %% [markdown]
# Tokenizador de SpaCy:
#
# 1. El texto crudo se segmenta por espacios, como cuando usamos text.split(' ')
# 2. El tokenizador recorre el texto de izquierda a derecha y, para cada substring o posible palabra encontrada, realiza dos verificaciones:
#
#     2.1. Evalúa si la posible palabra forma parte de alguna excepción y que entonces deba seguir alguna regla particular
#
#     2.2 Busca signos especiales como comas, paréntesis o comillas que puedan ser abiertos, cerrados o estar entre las palabras y deban separarse de ellas.
#
#     Si encuentra alguno de estos casos, el tokenizador separa la substring considerando estos caracteres y sigue recorriendo el texto.

# %% [markdown]
# Un posible caso de excepción:

# %%
excepcion = "bieniusté"

doc_ex = nlp(excepcion)

for token in doc_ex:
    print(token.text)
# Out:
# bieniusté

# %% [markdown]
# **Cómo agregar reglas que contemplen excepciones:**

# %%
special_case = [{'ORTH': u"bien", 'LEMMA': u"bien", 'POS': u"ADJ"},{'ORTH': 'i','LEMMA':'y','POS':'CCONJ'},
               {'ORTH':'usté','LEMMA':'usted','POS':'PRON'}]

nlp.tokenizer.add_special_case(u"bieniusté", special_case)

# vemos la nueva tokenización
print([w.text for w in nlp(u"bieniusté")]) 

# vemos la lematización de los tokens
print([w.lemma_ for w in nlp(u"bieniusté")])
# Out:
# ['bien', 'i', 'usté']
# ['bien', 'y', 'usted']

# %% [markdown]
# **Cómo armar un tokenizador propio:**

# %% [markdown]
# El tokenizador que incorporemos a nuestro pipeline debe tomar como input un texto y devolver un objeto Doc que pueda integrarse con el resto de los componentes.

# %%
from nltk import word_tokenize
from spacy.tokens import Doc

class NLTKTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        # Aquí le indicamos al tokenizador qué queremos que haga cuando lo llamamos
        words = word_tokenize(text)
        # Todos los tokens poseen un espacio que le sigue
        spaces = [True] * len(words)
        return Doc(self.vocab, words=words, spaces=spaces)

# %% [markdown]
# Cambiamos el tokenizador por defecto por el de NLTK que importamos y vemos qué pasa:

# %%
# instanciamos el tokenizador con un vocabulario
#nlp_parser.tokenizer = NLTKTokenizer(nlp.vocab)

nlp_parser = NLTKTokenizer(nlp.vocab)

doc_excepcion = nlp_parser(excepcion)

ex_tokens = [token.text for token in nlp_parser(excepcion)]
ex_tokens
# Out:
# ['bieniusté']

# %% [markdown]
# También podría ser que nos interesase conocer las palabras que se encuentran alredeor los tokens. El método ```nbor``` nos permite acceder a esta información:

# %%
n_words = 4

for token in doc:
    if token.text == "Irene":
        circundantes = [token.nbor(i) for i in range(1,n_words)]
        print(token.i, token.text)
        print(circundantes)
# Out:
# 50 Irene
# [y, yo, a]
# 97 Irene
# [las, últimas, habitaciones]
# 164 Irene
# [rechazó, dos, pretendientes]
# 265 Irene
# [era, una, chica]
# 322 Irene
# [no, era, así]
# 395 Irene
# [tenía, fe, en]
# 461 Irene
# [,, porque, yo]
# 474 Irene
# [sin, el, tejido]
# 535 Irene
# [qué, pensaba, hacer]
# 564 Irene
# [solamente, la, entretenía]
# 833 Irene
# [y, yo, vivíamos]
# 967 Irene
# [estaba, tejiendo, en]
# 1136 Irene
# [:,
#  	, —Tuve]
# 1257 Irene
# [extrañaba, unas, carpetas]
# 1282 Irene
# [pensó, en, una]
# 1375 Irene
# [se, acostumbró, a]
# 1406 Irene
# [cocinaría, platos, para]
# 1443 Irene
# [y, las, fuentes]
# 1452 Irene
# [estaba, contenta, porque]
# 1518 Irene
# [que, era, más]
# 1525 Irene
# [decía, :,
#  	]
# 1597 Irene
# [soñaba, en, alta]
# 1631 Irene
# [decía, que, mis]
# 1763 Irene
# [cantaba, canciones, de]
# 1835 Irene
# [empezaba, a, soñar]
# 1871 Irene
# [que, iba, hasta]
# 1921 Irene
# [le, llamó, la]
# 1992 Irene
# [y, la, hice]
# 2047 Irene
# [., El, tejido]
# 2150 Irene
# [(, yo, creo]

# %% [markdown]
# # 5. Etiquetado

# %% [markdown]
# Lugo de tokenizar, el pipeline de SpaCy etiquetar y parsea el Doc.Para ello, usa un modelo estadísico para predecir cuál es el tag o etiqueta más adecuado para el contexto.
#
# La información que podemos extraer de estas etiquetas es la siguiente:

# %% [markdown]
# - **Text:** Texto de la palabra original.
# - **Lemma:** Forma base de la palabra
# - **POS:** POS tag simple..
# - **Tag:** POS tag detallado.
# - **Dep:** Dependencia sintáctica.
# - **Shape:** Forma de la palabra - puntuación, dígitos, mayúsculas.
# - **is alpha:** ¿El token es alfabético?
# - **is stop:** ¿El token es una stopword?

# %%
import pandas as pd

tokens_info = {'text':[],
              'lemma':[],
              'pos':[],
              'tag':[],
              'dep':[],
              'shape':[],
              'is_alpha':[],
              'is_stop':[]}
    

for token in doc:
    tokens_info['text'].append(token.text)
    tokens_info['lemma'].append(token.lemma_)
    tokens_info['pos'].append(token.pos_)
    tokens_info['tag'].append(token.tag_)
    tokens_info['dep'].append(token.dep_)
    tokens_info['shape'].append(token.shape_)
    tokens_info['is_alpha'].append(token.is_alpha)
    tokens_info['is_stop'].append(token.is_stop)
    
df = pd.DataFrame(tokens_info)
df.head()
# Out:
#       text    lemma    pos                                                tag  \
# 0     CASA     CASA   NOUN                       NOUN__Gender=Fem|Number=Sing
# 1   TOMADA   TOMADA  PROPN                                           PROPN___
# 2  \n\n \t  \n\n \t  SPACE                                                _SP
# 3      Nos      Nos   PRON            PRON__Number=Plur|Person=1|PronType=Prs
# 4  gustaba   gustar   VERB  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|...
#
#      dep    shape  is_alpha  is_stop
# 0  nsubj     XXXX      True    False
# 1   amod     XXXX      True    False
# 2         \n\n \t     False    False
# 3    obj      Xxx      True     True
# 4   ROOT     xxxx      True    False

# %% [markdown]
# Si tenemos dudas sobre las etiquetas, podemos obtener un poco más de información sobre ellas de la siguiente manera:

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %% [markdown]
# **Cómo funciona el sistema de etiquetado:**
#
# 1. El tokenizador consulta si existen excpciones de tokenización que impliquen que una secuencia de caracteres se mapee con más de un token, y le asigna una etiqueta POS a cada token encontrado.
#
# 2. Luego, se le asigna a cada token una etiqueta POS extendida con la información morfológica (```tag_```).
#
# 3. Si algún token no recibió una etiqueta POS en el proceso anterior, se utiliza una tabla de mapeo para estableces sus etiquetas.
#
# 4. Por último, una regla determinísitca establece cuál es el lema del token en cuestión, considerando tanto la etiqueta POS como la información morfológica encontrada. En el caso del inglés, también se pueden utilizar archivos de excepciones provistos por [WordNet](https://wordnet.princeton.edu/).

# %% [markdown]
# **Links útiles:**
#
# [Universal POS tags](https://universaldependencies.org/u/pos/)
#
# [Mapeo de tags para español](https://github.com/explosion/spaCy/blob/master/spacy/lang/es/tag_map.py)

# %% [markdown]
# ## 6. Parseo de dependencias

# %%
sentences = [sent for sent in doc.sents]
sentences[6]
# Out:
# Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió María Esther antes que llegáramos a comprometernos.

# %%
options = {"compact": True,"bg": "#09a3d5", "distances":1,
           "color": "white", "font": "Source Sans Pro"}

displacy.render(sentences[6], style="dep", jupyter=True, options=options)

# para ver en otra página
# displacy.serve(sentences[6], style="dep", options=options)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="bd34ee1566ca438eb6ae63748f96ad8f-0" class="displacy" width="2900" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Irene</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">rechazó</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">dos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">pretendientes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">sin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">mayor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">motivo,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">mí</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">murió</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">María</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Esther</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">antes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">llegáramos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">comprometernos.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-0" stroke-width="2px" d="M62,377.0 62,352.0 188.0,352.0 188.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-1" stroke-width="2px" d="M362,377.0 362,352.0 488.0,352.0 488.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,379.0 L358,371.0 366,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-2" stroke-width="2px" d="M212,377.0 212,327.0 491.0,327.0 491.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M491.0,379.0 L495.0,371.0 487.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-3" stroke-width="2px" d="M662,377.0 662,327.0 941.0,327.0 941.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,379.0 L658,371.0 666,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-4" stroke-width="2px" d="M812,377.0 812,352.0 938.0,352.0 938.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd34ee1566ca438eb6ae63748f96ad8f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,379.0 L808,371.0 816,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd34e

# %% [markdown]
# **Noun chunks**
#
# Un noun chunk es una frase nominal base (NP en inglés) que no contiene otra frase nominal incrustada (i.e. no contiene coordinación nominal, frases preposicionales ni cláusulas relativas).
#
# SpaCy contiene algunos métodos que nos permiten acceder a la información de estas porciones de texto:
#
# - Text: texto original
# - Root.text: texto original de la palabra que conecta el chunk con el resto de la oracion (núcleo del chunk)
# - Root.dep_: relación de dependencia que conecta el núcleo del chunk con el núcleo de laoración donde se inserta
# - Root_head text: núcleo de la oración donde se encuentra el chunk

# %%
print(sentences[6].text, end='\n\n')
sent6 = nlp(sentences[6].text)

print('{0:30} {1:15} {2:15} {3}'.format('text','root','dep','head'), end='\n\n')

for chunk in sent6.noun_chunks:
    print('{0:30} {1:15} {2:15} {3}'.format(chunk.text, 
                                            chunk.root.text, 
                                            chunk.root.dep_, 
                                            chunk.root.head.text))
# Out:
# Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió María Esther antes que llegáramos a comprometernos.
#
# text                           root            dep             head
#
# Irene                          Irene           nsubj           rechazó
# pretendientes                  pretendientes   obj             rechazó
# motivo                         motivo          obl             rechazó
# mí                             mí              obj             murió
# se                             se              obj             murió
# me                             me              obj             murió
# María Esther                   María           nsubj           murió

# %%
print('{0:15} {1:15} {2:15} {3:15} {4}'.format('text','dep','head text','head pos', 'children'), end='\n\n')

for token in sent6:
    print('{0:15} {1:15} {2:15} {3:15} {4}'.format(token.text, 
                                                   token.dep_, 
                                                   token.head.text, 
                                                   token.head.pos_,
                                                   [child for child in token.children]))

# %% [markdown]
# Así como podemos ver los nodos hijos de un token, también podemos ver sus  nodos padres o ancestrales:

# %%
for token in sent6:
    print('{0:15} {1}'.format(token.text,
                           [ant for ant in token.ancestors]))

# %% [markdown]
# **Links útiles:**
#
# [Online demo para visualizar parseos de dependencias](https://explosion.ai/demos/displacy)

# %% [markdown]
# ## 7. Segmentación de oraciones

# %% [markdown]
# SpaCy utiliza el parser de dependencias para determinar los límites de las oraciones en lugar de hacerlo mediante reglas. Esto hace que los límites encontrados dependan del modelo estadístico que se haya entrenado previamente. Sin embargo, también es posible añadir patrones de delimitación o cambiar el segmentador por otro.

# %%
i = 1
for sent in doc.sents:
    print('ORACIÓN',i)
    print(sent.text)
    print('-----')
    i += 1
# Out:
# ORACIÓN 1
# CASA TOMADA
#
#  	Nos gustaba la casa porque aparte de espaciosa y antigua (hoy que las casas antiguas sucumben a la más ventajosa liquidación de sus materiales) guardaba los recuerdos de nuestros bisabuelos, el abuelo paterno, nuestros padres y toda la infancia.
#
# -----
# ORACIÓN 2
# Nos habituamos Irene y yo a persistir solos en ella, lo que era una locura pues en esa casa podían vivir ocho personas sin estorbarse.
# -----
# ORACIÓN 3
# Hacíamos la limpieza por la mañana, levantándonos a las siete, y a eso de las once yo le dejaba a Irene las últimas habitaciones por repasar y me iba a la cocina.
# -----
# ORACIÓN 4
# Almorzábamos a mediodía, siempre puntuales; ya no quedaba nada por hacer fuera de unos pocos platos sucios.
# -----
# ORACIÓN 5
# Nos resultaba grato almorzar pensando en la casa profunda y silenciosa y cómo nos bastábamos para mantenerla limpia.
# -----
# ORACIÓN 6
# A veces llegamos a creer que era ella la que no nos dejó casarnos.
# -----
# ORACIÓN 7
# Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió María Esther antes que llegáramos a comprometernos.
# -----
# ORACIÓN 8
# Entramos en los cuarenta años con la inexpresada idea de que el nuestro, simple y silencioso matrimonio de hermanos, era necesaria clausura de la genealogía asentada por los bisabuelos en nuestra casa.
# -----
# ORACIÓN 9
# Nos moriríamos allí algún día, vagos y esquivos primos se quedarían con la casa y la echarían al suelo para enriquecerse con el terreno y los ladrillos; o mejor, nosotros mismos la voltearíamos justicieramente antes de que fuese demasiado tarde.
#
# -----
# ORACIÓN 10
# Irene era una chica nacida para no molestar a nadie.
# -----
# ORACIÓN 11
# Aparte de su actividad matinal se pasaba el resto del día tejiendo en el sofá de su dormitorio.
# -----
# ORACIÓN 12
# No sé por qué tejía tanto, yo creo que las mujeres tejen cuando han encontrado en esa labor el gran pretexto para no hacer nada.
# -----
# ORACIÓN 13
# Irene no era así, tejía cosas siempre necesarias, tricotas para el invierno, medias para mí, mañanitas y chalecos para ella.
# -----
# ORACIÓN 14
# A veces tejía un chaleco y después lo destejía en un momento porque algo no le agradaba; era gracioso ver en la canastilla el montón de lana encrespada resistiéndose a perder su forma de algunas horas.
# -----
# ORACIÓN 15
# Los sábados iba yo al centro a comprarle lana; Irene tenía fe en mi gusto, se complacía con los colores y nunca tuve que devolver madejas.
# -----
# ORACIÓN 16
# Yo aprovechaba esas salidas para dar una vuelta por las librerías y preguntar vanamente si había novedades en literatura francesa.
# -----
# ORACIÓN 17
# Desde 1939 no llegaba nada valioso a la Argentina.
#
# -----
# ORACIÓN 18
# Pero es de la casa que me interesa hablar, de la casa y de Irene, porque yo no tengo importancia.
# -----
# ORACIÓN 19
# Me pregunto qué hubiera hecho Irene sin el tejido.
# -----
# ORACIÓN 20
# Uno puede releer un libro, pero cuando un pullover está terminado no se puede repetirlo sin escándalo.
# -----
# ORACIÓN 21
# Un día encontré el cajón de abajo de la cómoda de alcanfor lleno de pañoletas blancas, verdes, lila.
# -----
# ORACIÓN 22
# Estaban con naftalina, apiladas como en una mercería; no tuve valor de preguntarle a Irene qué pensaba hacer con ellas.
# -----
# ORACIÓN 23
# No necesitábamos ganarnos la vida, todos los meses llegaba la plata de los campos y el dinero aumentaba.
# -----
# ORACIÓN 24
# Pero a Irene solamente la entretenía el tejido, mostraba una destreza maravillosa y a mí se me iban las horas viéndole las manos como erizos plateados, agujas yendo y viniendo y una o dos canastillas en el suelo donde se agitaban constantemente los ovillos.
# -----
# ORACIÓN 25
# Era hermoso.
#
# -----
# ORACIÓN 26
# Cómo no acordarme de la distribución de la casa.
# -----
# ORACIÓN 27
# El comedor, una sala con gobelinos, la biblioteca y tres dormitorios grandes quedaban en la parte más retirada, la que mira hacia Rodríguez Peña.
# -----
# ORACIÓN 28
# Solamente un pasillo con su maciza puerta de roble aislaba esa parte del ala delantera donde había un baño, la cocina, nuestros dormitorios y el living central, al cual comunicaban los dormitorios y el pasillo.
# -----
# ORACIÓN 29
# Se entraba a la casa por un zaguán con mayólica, y la puerta cancel daba al living.
# -----
# ORACIÓN 30
# De manera que uno entraba por el zaguán, abría la cancel y pasaba al living; tenía a los lados las puertas de nuestros dormitorios, y al frente el pasillo que conducía a la parte más retirada; avanzando por el pasillo se franqueaba la puerta de roble y más allá empezaba el otro lado de la casa, o bien se podía girar a la izquierda justamente antes de la puerta y seguir por un pasillo más estrecho que llevaba a la cocina y el baño.
# -----
# ORACIÓN 31
# Cuando la puerta estaba abierta advertía uno que la casa era muy grande; si no, daba la impresión de un departamento de los que se edifican ahora, apenas para moverse; Irene y yo vivíamos siempre en esta parte de la casa, casi nunca íbamos más allá de la puerta de roble, salvo para hacer la limpieza, pues es increíble cómo se junta tierra en los muebles.
# -----
# ORACIÓN 32
# Buenos Aires será una ciudad limpia, pero eso lo debe a sus habitantes y no a otra cosa.
# -----
# ORACIÓN 33
# Hay demasiada tierra en el aire, apenas sopla una ráfaga se palpa el polvo en los mármoles de las consolas y entre los rombos de las carpetas de macramé; da trabajo sacarlo bien con plumero, vuela y se suspende en el aire, un momento después se deposita de nuevo en los muebles y los pianos.
#
# -----
# ORACIÓN 34
# Lo recordaré siempre con claridad porque fue simple y sin circunstancias inútiles.
# -----
# ORACIÓN 35
# Irene estaba tejiendo en su dormitorio, eran las ocho de la noche y de repente se me ocurrió poner al fuego la pavita del mate.
# -----
# ORACIÓN 36
# Fui por el pasillo hasta enfrentar la entornada puerta de roble, y daba la vuelta al codo que llevaba a la cocina cuando escuché algo en el comedor o la biblioteca.
# -----
# ORACIÓN 37
# El sonido venía impreciso y sordo, como un volcarse de silla sobre la alfombra o un ahogado susurro de conversación.
# -----
# ORACIÓN 38
# También lo oí, al mismo tiempo o un segundo después, en el fondo del pasillo que traía desde aquellas piezas hasta la puerta.
# -----
# ORACIÓN 39
# Me tiré contra la puerta antes de que fuera demasiado tarde, la cerré de golpe apoyando el cuerpo; felizmente la llave estaba puesta de nuestro lado y además corrí el gran cerrojo para más seguridad.
#
# -----
# ORACIÓN 40
# Fui a la cocina, calenté la pavita, y cuando estuve de vuelta con la bandeja del mate le dije a Irene:
#  	—Tuve que cerrar la puerta del pasillo.
# -----
# ORACIÓN 41
# Han tomado la parte del fondo.
#
# -----
# ORACIÓN 42
# Dejó caer el tejido y me miró con sus graves ojos cansados.
#
# -----
# ORACIÓN 43
# —¿Estás seguro?
#
# -----
# ORACIÓN 44
# Asentí.
#
# -----
# ORACIÓN 45
# —Entonces —dijo recogiendo las agujas— tendremos que vivir en este lado.
#
# -----
# ORACIÓN 46
# Yo cebaba el mate con mucho cuidado, pero ella tardó un rato en reanudar su labor.
# -----
# ORACIÓN 47
# Me acuerdo que tejía un chaleco gris; a mí me gustaba ese chaleco.
#
# -----
# ORACIÓN 48
# Los primeros días nos pareció penoso porque ambos habíamos dejado en la parte tomada muchas cosas que queríamos.
# -----
# ORACIÓN 49
# Mis libros de literatura francesa, por ejemplo, estaban todos en la biblioteca.
# -----
# ORACIÓN 50
# Irene extrañaba unas carpetas, un par de pantuflas que tanto la abrigaban en invierno.
# -----
# ORACIÓN 51
# Yo sentía mi pipa de enebro y creo que Irene pensó en una botella de Hesperidina de muchos años.
# -----
# ORACIÓN 52
# Con frecuencia (pero esto solamente sucedió los primeros días) cerrábamos algún cajón de las cómodas y nos mirábamos con tristeza.
#
# -----
# ORACIÓN 53
# —No está aquí.
#
# -----
# ORACIÓN 54
# Y era una cosa más de todo lo que habíamos perdido al otro lado de la casa.
#
# -----
# ORACIÓN 55
# Pero también tuvimos ventajas.
# -----
# ORACIÓN 56
# La limpieza se simplificó tanto que aun levantándose tardísimo, a las nueve y media por ejemplo, no daban las once y ya estábamos de brazos cruzados.
# -----
# ORACIÓN 57
# Irene se acostumbró a ir conmigo a la cocina y ayudarme a preparar el almuerzo.
# -----
# ORACIÓN 58
# Lo pensamos bien, y se decidió esto: mientras yo preparaba el almuerzo, Irene cocinaría platos para comer fríos de noche.
# -----
# ORACIÓN 59
# Nos alegramos porque siempre resulta molesto tener que abandonar los dormitorios al atardecer y ponerse a cocinar.
# -----
# ORACIÓN 60
# Ahora nos bastaba con la mesa en el dormitorio de Irene y las fuentes de comida fiambre.
#
# -----
# ORACIÓN 61
# Irene estaba contenta porque le quedaba más tiempo para tejer.
# -----
# ORACIÓN 62
# Yo andaba un poco perdido a causa de los libros, pero por no afligir a mi hermana me puse a revisar la colección de estampillas de papá, y eso me sirvió para matar el tiempo.
# -----
# ORACIÓN 63
# Nos divertíamos mucho, cada uno en sus cosas, casi siempre reunidos en el dormitorio de Irene que era más cómodo.
# -----
# ORACIÓN 64
# Aveces Irene decía:
#  	—Fíjate este punto que se me ha ocurrido.
# -----
# ORACIÓN 65
# ¿No da un dibujo de trébol?
#
# -----
# ORACIÓN 66
# Un rato después era yo el que le ponía ante los ojos un cuadradito de papel para que viese el mérito de algún sello de Eupen y Malmédy.
# -----
# ORACIÓN 67
# Estábamos bien, y poco a poco empezábamos a no pensar.
# -----
# ORACIÓN 68
# Se puede vivir sin pensar.
#
# -----
# ORACIÓN 69
# (Cuando Irene soñaba en alta voz yo me desvelaba en seguida.
# -----
# ORACIÓN 70
# Nunca pude habituarme a esa voz de estatua o papagayo, voz que viene de los sueños y no de la garganta.
# -----
# ORACIÓN 71
# Irene decía que mis sueños consistían en grandes sacudones que a veces hacían caer el cobertor.
# -----
# ORACIÓN 72
# Nuestros dormitorios tenían el living de por medio, pero de noche se escuchaba cualquier cosa en la casa.
# -----
# ORACIÓN 73
# Nos oíamos respirar, toser, presentíamos el ademán que conduce a la llave del velador, los mutuos y frecuentes insomnios.
#
# -----
# ORACIÓN 74
# Aparte de eso todo estaba callado en la casa.
# -----
# ORACIÓN 75
# De día eran los rumores domésticos, el roce metálico de las agujas de tejer, un crujido al pasar las hojas del álbum filatélico.
# -----
# ORACIÓN 76
# La puerta de roble, creo haberlo dicho, era maciza.
# -----
# ORACIÓN 77
# En la cocina y el baño, que quedaban tocando la parte tomada, nos poníamos a hablar en voz más alta o Irene cantaba canciones de cuna.
# -----
# ORACIÓN 78
# En una cocina hay demasiado ruido de loza y vidrios para que otros sonidos irrumpan en ella.
# -----
# ORACIÓN 79
# Muy pocas veces permitíamos allí el silencio, pero cuando tornábamos a los dormitorios y al living, entonces la casa se ponía callada y a media luz, hasta pisábamos más despacio para no molestarnos.
# -----
# ORACIÓN 80
# Yo creo que era por eso que de noche, cuando Irene empezaba a soñar en alta voz, me desvelaba en seguida.
# -----
# ORACIÓN 81
# )
#  	Es casi repetir lo mismo salvo las consecuencias.
# -----
# ORACIÓN 82
# De noche siento sed, y antes de acostarnos le dije a Irene que iba hasta la cocina a servirme un vaso de agua.
# -----
# ORACIÓN 83
# Desde la puerta del dormitorio (ella tejía) oí el ruido en la cocina; tal vez en la cocina o tal vez en el baño porque el codo del pasillo apagaba el sonido.
# -----
# ORACIÓN 84
# A Irene le llamó la atención mi brusca manera de detenerme, y vino a mi lado sin decir palabra.
# -----
# ORACIÓN 85
# Nos quedamos escuchando los ruidos, notando claramente que eran de este lado de la puerta de roble, en la cocina y en el baño, o en el pasillo mismo donde empezaba el codo casi al lado nuestro.
#
# -----
# ORACIÓN 86
# No nos miramos siquiera.
# -----
# ORACIÓN 87
# Apreté el brazo de Irene y la hice correr conmigo hasta la puerta cancel, sin volvernos hacia atrás.
# -----
# ORACIÓN 88
# Los ruidos se oían más fuerte pero siempre sordos, a espaldas nuestras.
# -----
# ORACIÓN 89
# Cerré de un golpe la cancel y nos quedamos en el zaguán.
# -----
# ORACIÓN 90
# Ahora no se oía nada.
#
# -----
# ORACIÓN 91
# —Han tomado esta parte —dijo Irene.
# -----
# ORACIÓN 92
# El tejido le colgaba de las manos y las hebras iban hasta la cancel y se perdían debajo.
# -----
# ORACIÓN 93
# Cuando vio que los ovillos habían quedado del otro lado soltó el tejido sin mirarlo.
#
# -----
# ORACIÓN 94
# —¿Tuviste tiempo de traer alguna cosa?
# -----
# ORACIÓN 95
# —le pregunté inútilmente.
#
# -----
# ORACIÓN 96
# —No, nada.
#
# -----
# ORACIÓN 97
# Estábamos con lo puesto.
# -----
# ORACIÓN 98
# Me acordé de los quince mil pesos en el armario de mi dormitorio.
# -----
# ORACIÓN 99
# Ya era tarde ahora.
#
# -----
# ORACIÓN 100
# Como me quedaba el reloj pulsera, vi que eran las once de la noche.
# -----
# ORACIÓN 101
# Rodeé con mi brazo la cintura de Irene (yo creo que ella estaba llorando) y salimos a la calle.
# -----
# ORACIÓN 102
# Antes de alejarnos tuve lástima, cerré bien la puerta de entrada y tiré la llave a la alcantarilla.
# -----
# ORACIÓN 103
# No fuese que a algún pobre diablo se le ocurriera robar y se metiera en la casa, a esa hora y con la casa tomada.
# -----

# %% [markdown]
# Si chequeamos el árbol de dependencias, efectivamente vemos que el parser hace depender el título de la primera oración.

# %%
sent1 = nlp(sentences[0].text)
options={"distances":1}
displacy.render(sent1, style="dep", options=options, jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="dfa6d5acbb94404ca817fbc11e7a2836-0" class="displacy" width="7575" height="1099.5" direction="ltr" style="max-width: none; height: 1099.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">CASA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">TOMADA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">
#
#  	</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Nos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">gustaba</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">casa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">porque</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">aparte</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">espaciosa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">antigua (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">hoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">las</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">casas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">antiguas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">sucumben</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">más</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">ventajosa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">liquidación</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">sus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">materiales)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">guardaba</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">recuerdos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cu

# %% [markdown]
# Para solucionar esto, SpaCy nos ofrece dos estrategias:
#
# - Añadir un componente llamado ```sentencizer``` que separa las oraciones por signos de puntuación tales como el punto (.), el signo de pregunta (?) o el signo de exclamación (!)
# - Armar nuestro propio segmentador de oraciones basado en reglas y agregarlo al pipeline

# %% [markdown]
# Para armar un segmentador propio, debemos definir una función que establezca cuál será nuestro separador de oraciones.

# %%
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if re.search('\n\n',token.text):
            doc[token.i+1].is_sent_start = True
    return doc

# %% [markdown]
# Luego, agregamos nuestra función al pipeline y volvemos a cargar el documento para que realice la segmentación nuevamente.

# %%
nlp.add_pipe(set_custom_boundaries, name="sent_segmenter", before="parser")
nlp.pipe_names
# Out:
# ['tagger', 'sent_segmenter', 'parser', 'ner']

# %%
import re

doc = nlp(casa_tomada)
sentences_good = list()

i = 1
for sent in doc.sents:
    print('ORACIÓN',i)
    print(sent.text)
    sentences_good.append(sent.text.strip())
    print('-----')
    i += 1
# Out:
# ORACIÓN 1
# CASA TOMADA
#
#
# -----
# ORACIÓN 2
# Nos gustaba la casa porque aparte de espaciosa y antigua (hoy que las casas antiguas sucumben a la más ventajosa liquidación de sus materiales) guardaba los recuerdos de nuestros bisabuelos, el abuelo paterno, nuestros padres y toda la infancia.
#
# -----
# ORACIÓN 3
# Nos habituamos Irene y yo a persistir solos en ella, lo que era una locura pues en esa casa podían vivir ocho personas sin estorbarse.
# -----
# ORACIÓN 4
# Hacíamos la limpieza por la mañana, levantándonos a las siete, y a eso de las once yo le dejaba a Irene las últimas habitaciones por repasar y me iba a la cocina.
# -----
# ORACIÓN 5
# Almorzábamos a mediodía, siempre puntuales; ya no quedaba nada por hacer fuera de unos pocos platos sucios.
# -----
# ORACIÓN 6
# Nos resultaba grato almorzar pensando en la casa profunda y silenciosa y cómo nos bastábamos para mantenerla limpia.
# -----
# ORACIÓN 7
# A veces llegamos a creer que era ella la que no nos dejó casarnos.
# -----
# ORACIÓN 8
# Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió María Esther antes que llegáramos a comprometernos.
# -----
# ORACIÓN 9
# Entramos en los cuarenta años con la inexpresada idea de que el nuestro, simple y silencioso matrimonio de hermanos, era necesaria clausura de la genealogía asentada por los bisabuelos en nuestra casa.
# -----
# ORACIÓN 10
# Nos moriríamos allí algún día, vagos y esquivos primos se quedarían con la casa y la echarían al suelo para enriquecerse con el terreno y los ladrillos; o mejor, nosotros mismos la voltearíamos justicieramente antes de que fuese demasiado tarde.
#
# -----
# ORACIÓN 11
# Irene era una chica nacida para no molestar a nadie.
# -----
# ORACIÓN 12
# Aparte de su actividad matinal se pasaba el resto del día tejiendo en el sofá de su dormitorio.
# -----
# ORACIÓN 13
# No sé por qué tejía tanto, yo creo que las mujeres tejen cuando han encontrado en esa labor el gran pretexto para no hacer nada.
# -----
# ORACIÓN 14
# Irene no era así, tejía cosas siempre necesarias, tricotas para el invierno, medias para mí, mañanitas y chalecos para ella.
# -----
# ORACIÓN 15
# A veces tejía un chaleco y después lo destejía en un momento porque algo no le agradaba; era gracioso ver en la canastilla el montón de lana encrespada resistiéndose a perder su forma de algunas horas.
# -----
# ORACIÓN 16
# Los sábados iba yo al centro a comprarle lana; Irene tenía fe en mi gusto, se complacía con los colores y nunca tuve que devolver madejas.
# -----
# ORACIÓN 17
# Yo aprovechaba esas salidas para dar una vuelta por las librerías y preguntar vanamente si había novedades en literatura francesa.
# -----
# ORACIÓN 18
# Desde 1939 no llegaba nada valioso a la Argentina.
#
# -----
# ORACIÓN 19
# Pero es de la casa que me interesa hablar, de la casa y de Irene, porque yo no tengo importancia.
# -----
# ORACIÓN 20
# Me pregunto qué hubiera hecho Irene sin el tejido.
# -----
# ORACIÓN 21
# Uno puede releer un libro, pero cuando un pullover está terminado no se puede repetirlo sin escándalo.
# -----
# ORACIÓN 22
# Un día encontré el cajón de abajo de la cómoda de alcanfor lleno de pañoletas blancas, verdes, lila.
# -----
# ORACIÓN 23
# Estaban con naftalina, apiladas como en una mercería; no tuve valor de preguntarle a Irene qué pensaba hacer con ellas.
# -----
# ORACIÓN 24
# No necesitábamos ganarnos la vida, todos los meses llegaba la plata de los campos y el dinero aumentaba.
# -----
# ORACIÓN 25
# Pero a Irene solamente la entretenía el tejido, mostraba una destreza maravillosa y a mí se me iban las horas viéndole las manos como erizos plateados, agujas yendo y viniendo y una o dos canastillas en el suelo donde se agitaban constantemente los ovillos.
# -----
# ORACIÓN 26
# Era hermoso.
#
# -----
# ORACIÓN 27
# Cómo no acordarme de la distribución de la casa.
# -----
# ORACIÓN 28
# El comedor, una sala con gobelinos, la biblioteca y tres dormitorios grandes quedaban en la parte más retirada, la que mira hacia Rodríguez Peña.
# -----
# ORACIÓN 29
# Solamente un pasillo con su maciza puerta de roble aislaba esa parte del ala delantera donde había un baño, la cocina, nuestros dormitorios y el living central, al cual comunicaban los dormitorios y el pasillo.
# -----
# ORACIÓN 30
# Se entraba a la casa por un zaguán con mayólica, y la puerta cancel daba al living.
# -----
# ORACIÓN 31
# De manera que uno entraba por el zaguán, abría la cancel y pasaba al living; tenía a los lados las puertas de nuestros dormitorios, y al frente el pasillo que conducía a la parte más retirada; avanzando por el pasillo se franqueaba la puerta de roble y más allá empezaba el otro lado de la casa, o bien se podía girar a la izquierda justamente antes de la puerta y seguir por un pasillo más estrecho que llevaba a la cocina y el baño.
# -----
# ORACIÓN 32
# Cuando la puerta estaba abierta advertía uno que la casa era muy grande; si no, daba la impresión de un departamento de los que se edifican ahora, apenas para moverse; Irene y yo vivíamos siempre en esta parte de la casa, casi nunca íbamos más allá de la puerta de roble, salvo para hacer la limpieza, pues es increíble cómo se junta tierra en los muebles.
# -----
# ORACIÓN 33
# Buenos Aires será una ciudad limpia, pero eso lo debe a sus habitantes y no a otra cosa.
# -----
# ORACIÓN 34
# Hay demasiada tierra en el aire, apenas sopla una ráfaga se palpa el polvo en los mármoles de las consolas y entre los rombos de las carpetas de macramé; da trabajo sacarlo bien con plumero, vuela y se suspende en el aire, un momento después se deposita de nuevo en los muebles y los pianos.
#
# -----
# ORACIÓN 35
# Lo recordaré siempre con claridad porque fue simple y sin circunstancias inútiles.
# -----
# ORACIÓN 36
# Irene estaba tejiendo en su dormitorio, eran las ocho de la noche y de repente se me ocurrió poner al fuego la pavita del mate.
# -----
# ORACIÓN 37
# Fui por el pasillo hasta enfrentar la entornada puerta de roble, y daba la vuelta al codo que llevaba a la cocina cuando escuché algo en el comedor o la biblioteca.
# -----
# ORACIÓN 38
# El sonido venía impreciso y sordo, como un volcarse de silla sobre la alfombra o un ahogado susurro de conversación.
# -----
# ORACIÓN 39
# También lo oí, al mismo tiempo o un segundo después, en el fondo del pasillo que traía desde aquellas piezas hasta la puerta.
# -----
# ORACIÓN 40
# Me tiré contra la puerta antes de que fuera demasiado tarde, la cerré de golpe apoyando el cuerpo; felizmente la llave estaba puesta de nuestro lado y además corrí el gran cerrojo para más seguridad.
#
# -----
# ORACIÓN 41
# Fui a la cocina, calenté la pavita, y cuando estuve de vuelta con la bandeja del mate le dije a Irene:
#  	—Tuve que cerrar la puerta del pasillo.
# -----
# ORACIÓN 42
# Han tomado la parte del fondo.
#
# -----
# ORACIÓN 43
# Dejó caer el tejido y me miró con sus graves ojos cansados.
#
# -----
# ORACIÓN 44
# —¿Estás seguro?
#
# -----
# ORACIÓN 45
# Asentí.
#
# -----
# ORACIÓN 46
# —Entonces —dijo recogiendo las agujas— tendremos que vivir en este lado.
#
# -----
# ORACIÓN 47
# Yo cebaba el mate con mucho cuidado, pero ella tardó un rato en reanudar su labor.
# -----
# ORACIÓN 48
# Me acuerdo que tejía un chaleco gris; a mí me gustaba ese chaleco.
#
# -----
# ORACIÓN 49
# Los primeros días nos pareció penoso porque ambos habíamos dejado en la parte tomada muchas cosas que queríamos.
# -----
# ORACIÓN 50
# Mis libros de literatura francesa, por ejemplo, estaban todos en la biblioteca.
# -----
# ORACIÓN 51
# Irene extrañaba unas carpetas, un par de pantuflas que tanto la abrigaban en invierno.
# -----
# ORACIÓN 52
# Yo sentía mi pipa de enebro y creo que Irene pensó en una botella de Hesperidina de muchos años.
# -----
# ORACIÓN 53
# Con frecuencia (pero esto solamente sucedió los primeros días) cerrábamos algún cajón de las cómodas y nos mirábamos con tristeza.
#
# -----
# ORACIÓN 54
# —No está aquí.
#
# -----
# ORACIÓN 55
# Y era una cosa más de todo lo que habíamos perdido al otro lado de la casa.
#
# -----
# ORACIÓN 56
# Pero también tuvimos ventajas.
# -----
# ORACIÓN 57
# La limpieza se simplificó tanto que aun levantándose tardísimo, a las nueve y media por ejemplo, no daban las once y ya estábamos de brazos cruzados.
# -----
# ORACIÓN 58
# Irene se acostumbró a ir conmigo a la cocina y ayudarme a preparar el almuerzo.
# -----
# ORACIÓN 59
# Lo pensamos bien, y se decidió esto: mientras yo preparaba el almuerzo, Irene cocinaría platos para comer fríos de noche.
# -----
# ORACIÓN 60
# Nos alegramos porque siempre resulta molesto tener que abandonar los dormitorios al atardecer y ponerse a cocinar.
# -----
# ORACIÓN 61
# Ahora nos bastaba con la mesa en el dormitorio de Irene y las fuentes de comida fiambre.
#
# -----
# ORACIÓN 62
# Irene estaba contenta porque le quedaba más tiempo para tejer.
# -----
# ORACIÓN 63
# Yo andaba un poco perdido a causa de los libros, pero por no afligir a mi hermana me puse a revisar la colección de estampillas de papá, y eso me sirvió para matar el tiempo.
# -----
# ORACIÓN 64
# Nos divertíamos mucho, cada uno en sus cosas, casi siempre reunidos en el dormitorio de Irene que era más cómodo.
# -----
# ORACIÓN 65
# Aveces Irene decía:
#  	—Fíjate este punto que se me ha ocurrido.
# -----
# ORACIÓN 66
# ¿No da un dibujo de trébol?
#
# -----
# ORACIÓN 67
# Un rato después era yo el que le ponía ante los ojos un cuadradito de papel para que viese el mérito de algún sello de Eupen y Malmédy.
# -----
# ORACIÓN 68
# Estábamos bien, y poco a poco empezábamos a no pensar.
# -----
# ORACIÓN 69
# Se puede vivir sin pensar.
#
# -----
# ORACIÓN 70
# (Cuando Irene soñaba en alta voz yo me desvelaba en seguida.
# -----
# ORACIÓN 71
# Nunca pude habituarme a esa voz de estatua o papagayo, voz que viene de los sueños y no de la garganta.
# -----
# ORACIÓN 72
# Irene decía que mis sueños consistían en grandes sacudones que a veces hacían caer el cobertor.
# -----
# ORACIÓN 73
# Nuestros dormitorios tenían el living de por medio, pero de noche se escuchaba cualquier cosa en la casa.
# -----
# ORACIÓN 74
# Nos oíamos respirar, toser, presentíamos el ademán que conduce a la llave del velador, los mutuos y frecuentes insomnios.
#
# -----
# ORACIÓN 75
# Aparte de eso todo estaba callado en la casa.
# -----
# ORACIÓN 76
# De día eran los rumores domésticos, el roce metálico de las agujas de tejer, un crujido al pasar las hojas del álbum filatélico.
# -----
# ORACIÓN 77
# La puerta de roble, creo haberlo dicho, era maciza.
# -----
# ORACIÓN 78
# En la cocina y el baño, que quedaban tocando la parte tomada, nos poníamos a hablar en voz más alta o Irene cantaba canciones de cuna.
# -----
# ORACIÓN 79
# En una cocina hay demasiado ruido de loza y vidrios para que otros sonidos irrumpan en ella.
# -----
# ORACIÓN 80
# Muy pocas veces permitíamos allí el silencio, pero cuando tornábamos a los dormitorios y al living, entonces la casa se ponía callada y a media luz, hasta pisábamos más despacio para no molestarnos.
# -----
# ORACIÓN 81
# Yo creo que era por eso que de noche, cuando Irene empezaba a soñar en alta voz, me desvelaba en seguida.
# -----
# ORACIÓN 82
# )
#  	Es casi repetir lo mismo salvo las consecuencias.
# -----
# ORACIÓN 83
# De noche siento sed, y antes de acostarnos le dije a Irene que iba hasta la cocina a servirme un vaso de agua.
# -----
# ORACIÓN 84
# Desde la puerta del dormitorio (ella tejía) oí el ruido en la cocina; tal vez en la cocina o tal vez en el baño porque el codo del pasillo apagaba el sonido.
# -----
# ORACIÓN 85
# A Irene le llamó la atención mi brusca manera de detenerme, y vino a mi lado sin decir palabra.
# -----
# ORACIÓN 86
# Nos quedamos escuchando los ruidos, notando claramente que eran de este lado de la puerta de roble, en la cocina y en el baño, o en el pasillo mismo donde empezaba el codo casi al lado nuestro.
#
# -----
# ORACIÓN 87
# No nos miramos siquiera.
# -----
# ORACIÓN 88
# Apreté el brazo de Irene y la hice correr conmigo hasta la puerta cancel, sin volvernos hacia atrás.
# -----
# ORACIÓN 89
# Los ruidos se oían más fuerte pero siempre sordos, a espaldas nuestras.
# -----
# ORACIÓN 90
# Cerré de un golpe la cancel y nos quedamos en el zaguán.
# -----
# ORACIÓN 91
# Ahora no se oía nada.
#
# -----
# ORACIÓN 92
# —Han tomado esta parte —dijo Irene.
# -----
# ORACIÓN 93
# El tejido le colgaba de las manos y las hebras iban hasta la cancel y se perdían debajo.
# -----
# ORACIÓN 94
# Cuando vio que los ovillos habían quedado del otro lado soltó el tejido sin mirarlo.
#
# -----
# ORACIÓN 95
# —¿Tuviste tiempo de traer alguna cosa?
# -----
# ORACIÓN 96
# —le pregunté inútilmente.
#
# -----
# ORACIÓN 97
# —No, nada.
#
# -----
# ORACIÓN 98
# Estábamos con lo puesto.
# -----
# ORACIÓN 99
# Me acordé de los quince mil pesos en el armario de mi dormitorio.
# -----
# ORACIÓN 100
# Ya era tarde ahora.
#
# -----
# ORACIÓN 101
# Como me quedaba el reloj pulsera, vi que eran las once de la noche.
# -----
# ORACIÓN 102
# Rodeé con mi brazo la cintura de Irene (yo creo que ella estaba llorando) y salimos a la calle.
# -----
# ORACIÓN 103
# Antes de alejarnos tuve lástima, cerré bien la puerta de entrada y tiré la llave a la alcantarilla.
# -----
# ORACIÓN 104
# No fuese que a algún pobre diablo se le ocurriera robar y se metiera en la casa, a esa hora y con la casa tomada.
# -----

# %%
sentences_good[:3]
# Out:
# ['CASA TOMADA',
#  'Nos gustaba la casa porque aparte de espaciosa y antigua (hoy que las casas antiguas sucumben a la más ventajosa liquidación de sus materiales) guardaba los recuerdos de nuestros bisabuelos, el abuelo paterno, nuestros padres y toda la infancia.',
#  'Nos habituamos Irene y yo a persistir solos en ella, lo que era una locura pues en esa casa podían vivir ocho personas sin estorbarse.']

# %% [markdown]
# ## 8. NER

# %% [markdown]
# Un NER (Named Entity Recognition) es un sistema que no solo nos permite encontrar o reconocer entidades sino, además, saber de qué tipo son.
#
# Ahora bien, ¿qué es una entidad? ¿Cuántos tipos de entidades hay o puede haber? ¿Para qué puede servirnos reconocer entidades?

# %% [markdown]
# El NER de SpaCy nos permite reconocer los siguientes atributos de una entidad:
#
# - Text: texto original de la entidad
# - Start: índice de inicio de la entidad en el Doc
# - End: índice de finalización de la entidad en el Doc
# - LabeL: etiqueta de la entidad (tipo de entidad)

# %%
print(sentences_good[7])
sent7 = nlp(sentences_good[7])

for ent in sent7.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió María Esther antes que llegáramos a comprometernos.
# María Esther 67 79 ORG

# %%
print('{0:50} {1:10} {2:2} {3}'.format('text','start','end','label'),end='\n\n')

for ent in doc.ents:
    print('{0:50} {1:5} {2:8} {3}'.format(ent.text, ent.start_char, ent.end_char, ent.label_))
# Out:
# text                                               start      end label
#
# CASA TOMADA                                            0       11 ORG
# Nos gustaba la casa                                   15       34 MISC
# Hacíamos                                             398      406 MISC
# Irene                                                496      501 PER
# Almorzábamos a mediodía                              561      584 MISC
# Nos resultaba grato almorzar                         669      697 MISC
# A veces llegamos a creer                             786      810 MISC
# Irene                                                853      858 PER
# María Esther                                         920      932 PER
# Entramos                                             972      980 LOC
# Nos moriríamos allí algún día                       1174     1203 MISC
# Aparte                                              1475     1481 MISC
# No sé por qué tejía tanto                           1571     1596 MISC
# Irene                                               1700     1705 PER
# A veces tejía un chaleco                            1825     1849 MISC
# Los sábados iba yo al centro a comprarle lana       2027     2072 MISC
# Irene                                               2074     2079 PER
# Yo aprovechaba esas salidas                         2166     2193 MISC
# Desde 1939                                          2297     2307 MISC
# la Argentina                                        2334     2346 LOC
# Irene                                               2409     2414 PER
# Me pregunto qué hubiera hecho Irene sin el tejido   2448     2497 MISC
# Uno puede releer un libro                           2499     2524 MISC
# Un día encontré                                     2602     2617 MISC
# Estaban                                             2703     2710 MISC
# Irene                                               2788     2793 PER
# No necesitábamos ganarnos la vida                   2823     2856 MISC
# Pero a Irene                                        2928     2940 MISC
# Era hermoso.
#  	                                     3186     3201 MISC
# El comedor                                          3250     3260 MISC
# Rodríguez Peña                                      3380     3394 PER
# Solamente un pasillo                                3396     3416 MISC
# Se entraba a la casa por un zaguán                  3607     3641 MISC
# De manera                                           3691     3700 MISC
# Cuando la puerta                                    4126     4142 MISC
# Irene                                               4294     4299 PER
# Buenos Aires                                        4483     4495 LOC
# Hay demasiada tierra en el aire                     4572     4603 MISC
# Lo recordaré                                        4866     4878 MISC
# Irene                                               4949     4954 PER
# Fui por el pasillo                                  5077     5095 MISC
# El sonido venía impreciso y sordo                   5242     5275 MISC
# También                                             5359     5366 LOC
# Me tiré contra la puerta                            5485     5509 MISC
# Irene                                               5783     5788 PER
# Han tomado la parte del fondo                       5832     5861 MISC
# —¿Estás seguro?                                     5927     5942 MISC
# Asentí                                              5945     5951 MISC
# —Entonces —dijo                                     5955     5970 MISC
# Me acuerdo                                          6113     6123 MISC
# Los primeros días                                   6182     6199 MISC
# Mis libros de literatura francesa                   6295     6328 MISC
# Irene                                               6375     6380 PER
# Yo sentía mi pipa de enebro                         6462     6489 MISC
# Irene                                               6501     6506 PER
# Hesperidina                                         6531     6542 PER
# Con frecuencia                                      6559     6573 MISC
# La limpieza se simplificó                           6818     6843 MISC
# Irene                                               6968     6973 PER
# Lo pensamos bien                                    7048     7064 MISC
# Irene                                               7120     7125 PER
# Nos                                                 7170     7173 ORG
# Ahora                                               7285     7290 MISC
# Irene                                               7335     7340 PER
# Yo                                                  7439     7441 PER
# Nos divertíamos mucho                               7614     7635 MISC
# Irene                                               7702     7707 PER
# Aveces Irene                                        7728     7740 PER
# ¿No                                                 7792     7795 MISC
# Un rato después                                     7822     7837 MISC
# Eupen                                               7941     7946 LOC
# Malmédy                                             7949     7956 LOC
# Estábamos bien                                      7958     7972 MISC
# Se puede vivir sin pensar.
#  	                       8013     8042 MISC
# Cuando Irene                                        8043     8055 MISC
# Nunca pude                                          8103     8113 MISC
# Irene                                               8207     8212 PER
# Nuestros dormitorios tenían                         8303     8330 MISC
# Nos oíamos respirar                                 8409     8428 MISC
# De día                                              8579     8585 MISC
# La puerta de roble                                  8708     8726 MISC
# En la cocina y el baño                              8760     8782 MISC
# Irene                                               8862     8867 PER
# En una cocina                                       8895     8908 MISC
# Muy pocas veces permitíamos allí el silencio        8988     9032 MISC
# Yo creo que era                                     9187     9202 MISC
# Irene                                               9232     9237 PER
# De noche siento sed                                 9346     9365 MISC
# Irene                                               9399     9404 PER
# A Irene                                             9615     9622 PER
# Nos quedamos escuchando los ruidos                  9711     9745 MISC
# No nos miramos siquiera                             9907     9930 MISC
# Apreté                                              9932     9938 PER
# Irene                                               9951     9956 PER
# Los ruidos                                         10033    10043 MISC
# Cerré                                              10105    10110 MISC
# Ahora                                              10162    10167 MISC
# —dijo Irene                                        10209    10220 MISC
# El tejido le colgaba                               10222    10242 MISC
# Cuando vio que los ovillos habían quedado del otro 10311    10361 MISC
# Me acordé de los quince mil pesos en el armario de mi dormitorio 10503    10567 MISC
# Ya era tarde ahora.
#  	                             10569    10591 MISC
# Como me quedaba el reloj                           10591    10615 MISC
# Rodeé                                              10659    10664 PER
# Irene                                              10692    10697 LOC
# No fuese                                           10855    10863 MISC

# %%
for sent in sentences_good[1:]:
    print(sent, end='\n\n')
    s = nlp(sent)
    #print('{0:50} {1:10} {2:2} {3}'.format('text','start','end','label'),end='\n\n')
    for ent in s.ents:
        #print('{0:50} {1:5} {2:8} {3}'.format(ent.text, ent.start_char, ent.end_char, ent.label_))
        print(ent.text, ent.start_char, ent.end_char, ent.label_)
    print('-------------')
# Out:
# Nos gustaba la casa porque aparte de espaciosa y antigua (hoy que las casas antiguas sucumben a la más ventajosa liquidación de sus materiales) guardaba los recuerdos de nuestros bisabuelos, el abuelo paterno, nuestros padres y toda la infancia.
#
# -------------
# Nos habituamos Irene y yo a persistir solos en ella, lo que era una locura pues en esa casa podían vivir ocho personas sin estorbarse.
#
# Irene 15 20 PER
# -------------
# Hacíamos la limpieza por la mañana, levantándonos a las siete, y a eso de las once yo le dejaba a Irene las últimas habitaciones por repasar y me iba a la cocina.
#
# Irene 98 103 PER
# -------------
# Almorzábamos a mediodía, siempre puntuales; ya no quedaba nada por hacer fuera de unos pocos platos sucios.
#
# -------------
# Nos resultaba grato almorzar pensando en la casa profunda y silenciosa y cómo nos bastábamos para mantenerla limpia.
#
# -------------
# A veces llegamos a creer que era ella la que no nos dejó casarnos.
#
# -------------
# Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió María Esther antes que llegáramos a comprometernos.
#
# María Esther 67 79 ORG
# -------------
# Entramos en los cuarenta años con la inexpresada idea de que el nuestro, simple y silencioso matrimonio de hermanos, era necesaria clausura de la genealogía asentada por los bisabuelos en nuestra casa.
#
# -------------
# Nos moriríamos allí algún día, vagos y esquivos primos se quedarían con la casa y la echarían al suelo para enriquecerse con el terreno y los ladrillos; o mejor, nosotros mismos la voltearíamos justicieramente antes de que fuese demasiado tarde.
#
# -------------
# Irene era una chica nacida para no molestar a nadie.
#
# Irene 0 5 PER
# -------------
# Aparte de su actividad matinal se pasaba el resto del día tejiendo en el sofá de su dormitorio.
#
# -------------
# No sé por qué tejía tanto, yo creo que las mujeres tejen cuando han encontrado en esa labor el gran pretexto para no hacer nada.
#
# -------------
# Irene no era así, tejía cosas siempre necesarias, tricotas para el invierno, medias para mí, mañanitas y chalecos para ella.
#
# Irene 0 5 PER
# -------------
# A veces tejía un chaleco y después lo destejía en un momento porque algo no le agradaba; era gracioso ver en la canastilla el montón de lana encrespada resistiéndose a perder su forma de algunas horas.
#
# -------------
# Los sábados iba yo al centro a comprarle lana; Irene tenía fe en mi gusto, se complacía con los colores y nunca tuve que devolver madejas.
#
# Irene 47 52 PER
# -------------
# Yo aprovechaba esas salidas para dar una vuelta por las librerías y preguntar vanamente si había novedades en literatura francesa.
#
# -------------
# Desde 1939 no llegaba nada valioso a la Argentina.
#
# la Argentina 37 49 LOC
# -------------
# Pero es de la casa que me interesa hablar, de la casa y de Irene, porque yo no tengo importancia.
#
# Irene 59 64 PER
# -------------
# Me pregunto qué hubiera hecho Irene sin el tejido.
#
# Irene 30 35 PER
# -------------
# Uno puede releer un libro, pero cuando un pullover está terminado no se puede repetirlo sin escándalo.
#
# -------------
# Un día encontré el cajón de abajo de la cómoda de alcanfor lleno de pañoletas blancas, verdes, lila.
#
# -------------
# Estaban con naftalina, apiladas como en una mercería; no tuve valor de preguntarle a Irene qué pensaba hacer con ellas.
#
# Irene 85 90 PER
# -------------
# No necesitábamos ganarnos la vida, todos los meses llegaba la plata de los campos y el dinero aumentaba.
#
# -------------
# Pero a Irene solamente la entretenía el tejido, mostraba una destreza maravillosa y a mí se me iban las horas viéndole las manos como erizos plateados, agujas yendo y viniendo y una o dos canastillas en el suelo donde se agitaban constantemente los ovillos.
#
# Irene 7 12 PER
# -------------
# Era hermoso.
#
# -------------
# Cómo no acordarme de la distribución de la casa.
#
# Cómo 0 4 PER
# -------------
# El comedor, una sala con gobelinos, la biblioteca y tres dormitorios grandes quedaban en la parte más retirada, la que mira hacia Rodríguez Peña.
#
# Rodríguez Peña 130 144 PER
# -------------
# Solamente un pasillo con su maciza puerta de roble aislaba esa parte del ala delantera donde había un baño, la cocina, nuestros dormitorios y el living central, al cual comunicaban los dormitorios y el pasillo.
#
# -------------
# Se entraba a la casa por un zaguán con mayólica, y la puerta cancel daba al living.
#
# -------------
# De manera que uno entraba por el zaguán, abría la cancel y pasaba al living; tenía a los lados las puertas de nuestros dormitorios, y al frente el pasillo que conducía a la parte más retirada; avanzando por el pasillo se franqueaba la puerta de roble y más allá empezaba el otro lado de la casa, o bien se podía girar a la izquierda justamente antes de la puerta y seguir por un pasillo más estrecho que llevaba a la cocina y el baño.
#
# -------------
# Cuando la puerta estaba abierta advertía uno que la casa era muy grande; si no, daba la impresión de un departamento de los que se edifican ahora, apenas para moverse; Irene y yo vivíamos siempre en esta parte de la casa, casi nunca íbamos más allá de la puerta de roble, salvo para hacer la limpieza, pues es increíble cómo se junta tierra en los muebles.
#
# Irene 168 173 PER
# -------------
# Buenos Aires será una ciudad limpia, pero eso lo debe a sus habitantes y no a otra cosa.
#
# Buenos Aires 0 12 LOC
# -------------
# Hay demasiada tierra en el aire, apenas sopla una ráfaga se palpa el polvo en los mármoles de las consolas y entre los rombos de las carpetas de macramé; da trabajo sacarlo bien con plumero, vuela y se suspende en el aire, un momento después se deposita de nuevo en los muebles y los pianos.
#
# -------------
# Lo recordaré siempre con claridad porque fue simple y sin circunstancias inútiles.
#
# -------------
# Irene estaba tejiendo en su dormitorio, eran las ocho de la noche y de repente se me ocurrió poner al fuego la pavita del mate.
#
# Irene 0 5 PER
# -------------
# Fui por el pasillo hasta enfrentar la entornada puerta de roble, y daba la vuelta al codo que llevaba a la cocina cuando escuché algo en el comedor o la biblioteca.
#
# -------------
# El sonido venía impreciso y sordo, como un volcarse de silla sobre la alfombra o un ahogado susurro de conversación.
#
# -------------
# También lo oí, al mismo tiempo o un segundo después, en el fondo del pasillo que traía desde aquellas piezas hasta la puerta.
#
# -------------
# Me tiré contra la puerta antes de que fuera demasiado tarde, la cerré de golpe apoyando el cuerpo; felizmente la llave estaba puesta de nuestro lado y además corrí el gran cerrojo para más seguridad.
#
# -------------
# Fui a la cocina, calenté la pavita, y cuando estuve de vuelta con la bandeja del mate le dije a Irene:
#  	—Tuve que cerrar la puerta del pasillo.
#
# Irene 96 101 PER
# -------------
# Han tomado la parte del fondo.
#
# -------------
# Dejó caer el tejido y me miró con sus graves ojos cansados.
#
# -------------
# —¿Estás seguro?
#
# -------------
# Asentí.
#
# Asentí 0 6 LOC
# -------------
# —Entonces —dijo recogiendo las agujas— tendremos que vivir en este lado.
#
# —Entonces —dijo 0 15 MISC
# -------------
# Yo cebaba el mate con mucho cuidado, pero ella tardó un rato en reanudar su labor.
#
# -------------
# Me acuerdo que tejía un chaleco gris; a mí me gustaba ese chaleco.
#
# -------------
# Los primeros días nos pareció penoso porque ambos habíamos dejado en la parte tomada muchas cosas que queríamos.
#
# -------------
# Mis libros de literatura francesa, por ejemplo, estaban todos en la biblioteca.
#
# -------------
# Irene extrañaba unas carpetas, un par de pantuflas que tanto la abrigaban en invierno.
#
# Irene 0 5 PER
# -------------
# Yo sentía mi pipa de enebro y creo que Irene pensó en una botella de Hesperidina de muchos años.
#
# Irene 39 44 PER
# Hesperidina 69 80 PER
# -------------
# Con frecuencia (pero esto solamente sucedió los primeros días) cerrábamos algún cajón de las cómodas y nos mirábamos con tristeza.
#
# -------------
# —No está aquí.
#
# -------------
# Y era una cosa más de todo lo que habíamos perdido al otro lado de la casa.
#
# -------------
# Pero también tuvimos ventajas.
#
# -------------
# La limpieza se simplificó tanto que aun levantándose tardísimo, a las nueve y media por ejemplo, no daban las once y ya estábamos de brazos cruzados.
#
# -------------
# Irene se acostumbró a ir conmigo a la cocina y ayudarme a preparar el almuerzo.
#
# Irene 0 5 PER
# -------------
# Lo pensamos bien, y se decidió esto: mientras yo preparaba el almuerzo, Irene cocinaría platos para comer fríos de noche.
#
# Irene 72 77 PER
# -------------
# Nos alegramos porque siempre resulta molesto tener que abandonar los dormitorios al atardecer y ponerse a cocinar.
#
# -------------
# Ahora nos bastaba con la mesa en el dormitorio de Irene y las fuentes de comida fiambre.
#
# Irene 50 55 PER
# -------------
# Irene estaba contenta porque le quedaba más tiempo para tejer.
#
# Irene 0 5 PER
# -------------
# Yo andaba un poco perdido a causa de los libros, pero por no afligir a mi hermana me puse a revisar la colección de estampillas de papá, y eso me sirvió para matar el tiempo.
#
# -------------
# Nos divertíamos mucho, cada uno en sus cosas, casi siempre reunidos en el dormitorio de Irene que era más cómodo.
#
# Irene 88 93 PER
# -------------
# Aveces Irene decía:
#  	—Fíjate este punto que se me ha ocurrido.
#
# Aveces Irene 0 12 PER
# -------------
# ¿No da un dibujo de trébol?
# ¿No 0 3 MISC
# -------------
# Un rato después era yo el que le ponía ante los ojos un cuadradito de papel para que viese el mérito de algún sello de Eupen y Malmédy.
#
# Eupen 119 124 LOC
# Malmédy 127 134 LOC
# -------------
# Estábamos bien, y poco a poco empezábamos a no pensar.
#
# -------------
# Se puede vivir sin pensar.
#
# -------------
# (Cuando Irene soñaba en alta voz yo me desvelaba en seguida.
#
# Irene 8 13 PER
# -------------
# Nunca pude habituarme a esa voz de estatua o papagayo, voz que viene de los sueños y no de la garganta.
#
# -------------
# Irene decía que mis sueños consistían en grandes sacudones que a veces hacían caer el cobertor.
#
# -------------
# Nuestros dormitorios tenían el living de por medio, pero de noche se escuchaba cualquier cosa en la casa.
#
# -------------
# Nos oíamos respirar, toser, presentíamos el ademán que conduce a la llave del velador, los mutuos y frecuentes insomnios.
#
# -------------
# Aparte de eso todo estaba callado en la casa.
#
# -------------
# De día eran los rumores domésticos, el roce metálico de las agujas de tejer, un crujido al pasar las hojas del álbum filatélico.
#
# -------------
# La puerta de roble, creo haberlo dicho, era maciza.
#
# -------------
# En la cocina y el baño, que quedaban tocando la parte tomada, nos poníamos a hablar en voz más alta o Irene cantaba canciones de cuna.
#
# Irene 102 107 PER
# -------------
# En una cocina hay demasiado ruido de loza y vidrios para que otros sonidos irrumpan en ella.
#
# -------------
# Muy pocas veces permitíamos allí el silencio, pero cuando tornábamos a los dormitorios y al living, entonces la casa se ponía callada y a media luz, hasta pisábamos más despacio para no molestarnos.
#
# -------------
# Yo creo que era por eso que de noche, cuando Irene empezaba a soñar en alta voz, me desvelaba en seguida.
#
# Irene 45 50 PER
# -------------
# )
#  	Es casi repetir lo mismo salvo las consecuencias.
#
# -------------
# De noche siento sed, y antes de acostarnos le dije a Irene que iba hasta la cocina a servirme un vaso de agua.
#
# Irene 53 58 PER
# -------------
# Desde la puerta del dormitorio (ella tejía) oí el ruido en la cocina; tal vez en la cocina o tal vez en el baño porque el codo del pasillo apagaba el sonido.
#
# -------------
# A Irene le llamó la atención mi brusca manera de detenerme, y vino a mi lado sin decir palabra.
#
# Irene 2 7 PER
# -------------
# Nos quedamos escuchando los ruidos, notando claramente que eran de este lado de la puerta de roble, en la cocina y en el baño, o en el pasillo mismo donde empezaba el codo casi al lado nuestro.
#
# -------------
# No nos miramos siquiera.
#
# -------------
# Apreté el brazo de Irene y la hice correr conmigo hasta la puerta cancel, sin volvernos hacia atrás.
#
# Apreté 0 6 PER
# Irene 19 24 PER
# -------------
# Los ruidos se oían más fuerte pero siempre sordos, a espaldas nuestras.
#
# -------------
# Cerré de un golpe la cancel y nos quedamos en el zaguán.
#
# -------------
# Ahora no se oía nada.
#
# Ahora 0 5 MISC
# -------------
# —Han tomado esta parte —dijo Irene.
#
# —dijo Irene 23 34 MISC
# -------------
# El tejido le colgaba de las manos y las hebras iban hasta la cancel y se perdían debajo.
#
# -------------
# Cuando vio que los ovillos habían quedado del otro lado soltó el tejido sin mirarlo.
#
# -------------
# —¿Tuviste tiempo de traer alguna cosa?
#
# -------------
# —le pregunté inútilmente.
#
# -------------
# —No, nada.
#
# -------------
# Estábamos con lo puesto.
#
# -------------
# Me acordé de los quince mil pesos en el armario de mi dormitorio.
#
# -------------
# Ya era tarde ahora.
#
# -------------
# Como me quedaba el reloj pulsera, vi que eran las once de la noche.
#
# -------------
# Rodeé con mi brazo la cintura de Irene (yo creo que ella estaba llorando) y salimos a la calle.
#
# Rodeé 0 5 PER
# Irene 33 38 LOC
# -------------
# Antes de alejarnos tuve lástima, cerré bien la puerta de entrada y tiré la llave a la alcantarilla.
#
# -------------
# No fuese que a algún pobre diablo se le ocurriera robar y se metiera en la casa, a esa hora y con la casa tomada.
#
# -------------

# %%
print('{0:50} {1:10} {2:2} {3}'.format('text','start','end','label'),end='\n\n')

for sent in sentences_good[1:]:
    s = nlp(sent)
    for ent in s.ents:
        print('{0:50} {1:5} {2:8} {3}'.format(ent.text.strip(), ent.start_char, ent.end_char, ent.label_))
# Out:
# text                                               start      end label
#
# Irene                                                 15       20 PER
# Irene                                                 98      103 PER
# María Esther                                          67       79 ORG
# Irene                                                  0        5 PER
# Irene                                                  0        5 PER
# Irene                                                 47       52 PER
# la Argentina                                          37       49 LOC
# Irene                                                 59       64 PER
# Irene                                                 30       35 PER
# Irene                                                 85       90 PER
# Irene                                                  7       12 PER
# Cómo                                                   0        4 PER
# Rodríguez Peña                                       130      144 PER
# Irene                                                168      173 PER
# Buenos Aires                                           0       12 LOC
# Irene                                                  0        5 PER
# Irene                                                 96      101 PER
# Asentí                                                 0        6 LOC
# —Entonces —dijo                                        0       15 MISC
# Irene                                                  0        5 PER
# Irene                                                 39       44 PER
# Hesperidina                                           69       80 PER
# Irene                                                  0        5 PER
# Irene                                                 72       77 PER
# Irene                                                 50       55 PER
# Irene                                                  0        5 PER
# Irene                                                 88       93 PER
# Aveces Irene                                           0       12 PER
# ¿No                                                    0        3 MISC
# Eupen                                                119      124 LOC
# Malmédy                                              127      134 LOC
# Irene                                                  8       13 PER
# Irene                                                102      107 PER
# Irene                                                 45       50 PER
# Irene                                                 53       58 PER
# Irene                                                  2        7 PER
# Apreté                                                 0        6 PER
# Irene                                                 19       24 PER
# Ahora                                                  0        5 MISC
# —dijo Irene                                           23       34 MISC
# Rodeé                                                  0        5 PER
# Irene                                                 33       38 LOC

# %% [markdown]
# **Visualización:**

# %%
displacy.render(sent7, style="ent", jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     María Esther
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  antes que llegáramos a comprometernos.</div>

# %%
colors = {"ORG": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
options = {"ents": ["ORG"], "colors": colors}
displacy.render(sent7, style="ent", options=options, jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Irene rechazó dos pretendientes sin mayor motivo, a mí se me murió
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     María Esther
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  antes que llegáramos a comprometernos.</div>

# %% [markdown]
# Cómo agregar etiquetas sin entrenamiento:

# %%
from spacy.tokens import Span

ents = [(e.text, e.start_char, e.end_char, e.label_) for e in sent7.ents]
print('ANTES', ents)


PER = doc.vocab.strings[u"PER"]

per_ent = [Span(sent7, 0, 1, label=PER),Span(sent7, 13, 15, label=PER)]

sent7.ents = per_ent

ents = [(e.text, e.start_char, e.end_char, e.label_) for e in sent7.ents]
print('After', ents)
# Out:
# ANTES [('María Esther', 67, 79, 'ORG')]
# After [('Irene', 0, 5, 'PER'), ('María Esther', 67, 79, 'PER')]

# %% [markdown]
# Otra forma de accedet al tipo de oración es utilizando el atributo ent_type_ del token:

# %%
print(doc[97])
print(doc[97].ent_type_)
# Out:
# Irene
# PER

# %% [markdown]
# **Links útiles:**
#
# [Anotaciones del NER de Spacy](https://spacy.io/api/annotation#named-entities)

# %% [markdown]
# ## 9.Matcheo mediante reglas

# %% [markdown]
# Rules-base matcher es un componente de SpaCy que posibilita generar reglas con las que contrastar el texto y extraer los fragmentos que se adecúen a ellas. Lo interesante de este componente es que permite combinar expresiones regulares con las anotaciones lingüísticas de los modelos pre-entrenados.

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)

patternSV = [{"ORTH": "Irene", "DEP":'nsubj'},{"TEXT":{"REGEX":"\w+"},"OP":"*"},{"POS": "VERB", "DEP": "ROOT"},]
patternVS = [{"POS": "VERB", "DEP": "ROOT"},{"TEXT":{"REGEX":"\w+"},"OP":"*"},{"ORTH": "Irene", "DEP":'nsubj'}]
patternCOP = [{"ORTH": "Irene", "DEP":'nsubj'},{"TEXT":{"REGEX":"\w+"},"OP":"*"},{"LEMMA":"ser"}]

matcher.add("IreneSV", None, patternSV)
matcher.add("IreneVS", None, patternVS)
matcher.add("IreneCOP", None, patternCOP)

matched_sents = list()

for sent in sentences_good[1:]:
    s = nlp(sent)
    matches = matcher(s)
    match_ents = list()
    if len(matches) > 0:
        for match in matches:
            match_id, start, end = match
            span = s[start:end]
            info_match = {
                "start": span.start_char,
                "end": span.end_char,
                "label": "MATCH"
            }
            match_ents.append(info_match)            
        matched_sents.append({"text": sent, "ents": match_ents})

        
colors = {"MATCH": "linear-gradient(90deg, #b7deed, #49a5bf)"}
options = {"ents": ["MATCH"], "colors": colors}
displacy.render(matched_sents, style="ent", options=options, jupyter=True, manual=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-7b96cf1296f9> in <module>
#      32 colors = {"MATCH": "linear-gradient(90deg, #b7deed, #49a5bf)"}
#      33 options = {"ents": ["MATCH"], "colors": colors}
# ---> 34 displacy.render(matched_sents, style="ent", options=options, jupyter=True)
#
# ~/proyectos/2019_cursoNLP/lib/python3.6/site-packages/spacy/displacy/__init__.py in render(docs, style, page, minify, jupyter, options, manual)
#      49     renderer, converter = factories[style]
#      50     renderer = renderer(options=options)
# ---> 51     parsed = [converter(doc, options) for doc in docs] if not manual else docs
#      52     _html["parsed"] = renderer.render(parsed, page=page, minify=minify).strip()
#      53     html = _html["parsed"]
#
# ~/proyectos/2019_cursoNLP/lib/python3.6/site-packages/spacy/displacy/__init__.py in <listcomp>(.0)
#      49     renderer, converter = factories[style]
#      50     renderer = renderer(options=options)
# ---> 51     parsed = [converter(doc, options) for doc in docs] if not manual else docs
#      52     _html["parsed"] = renderer.render(parsed, page=page, minify=minify).strip()
#      53     html = _html["parsed"]
#
# ~/proyectos/2019_cursoNLP/lib/python3.6/site-packages/spacy/displacy/__init__.py in parse_ents(doc, options)
#     173     ents = [
#     174         {"start": ent.start_char, "end": ent.end_char, "label": ent.label_}
# --> 175         for ent in doc.ents
#     176     ]
#     177     if not ents:
#
# AttributeError: 'dict' object has no attribute 'ents'

# %% [markdown]
# [Matcheo mediante reglas](https://explosion.ai/demos/matcher)
#
# [Atributos disponibles para tokens](https://spacy.io/api/token#attributes)
